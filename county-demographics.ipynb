# %% [markdown]
# # US County Demographics
#
# In this project, we will be analyzing demographics data on US counties betwen 2010-2019 using a __[dataset obtained from Kaggle](https://www.kaggle.com/datasets/mexwell/us-country-demographics)__. The primary focus of this project is to utilize advanced SQL queries, pandas, and Tableau dashboarding to explore and visualize information regarding US counties. The table below provides information on each of the columns found in the dataset:

# %% [markdown]
# | Original Column Name | Renamed Column Name | Data Type | Description |
# |:---------------:|:-----------------:|:-----------------|:-----------|
# | County | County | String | County name |
# | State | State | String | State name |
# | Age.Percent 65 and Older | Age 65+ | Float | Estimated percentage of population whose ages are equal or greater than 65 years old are produced for the United States states and counties as well as for the Commonwealth of Puerto Rico and its municipios (county-equivalents for Puerto Rico). |
# | Age.Percent Under 18 Years | Age Under 18 | Float | Estimated percentage of population whose ages are under 18 years old are produced for the United States states and counties as well as for the Commonwealth of Puerto Rico and its municipios (county-equivalents for Puerto Rico). |
# | Age.Percent Under 5 Years	| Age Under 5 | Float | Estimated percentage of population whose ages are under 5 years old are produced for the United States states and counties as well as for the Commonwealth of Puerto Rico and its municipios (county-equivalents for Puerto Rico). |
# | Education.Bachelor's Degree or Higher	| Education Bachelor's+ | Float	| Percentage for the people who attended college but did not receive a degree and people who received an associate's bachelor's master's or professional or doctorate degree. These data include only persons 25 years old and over. The percentages are obtained by dividing the counts of graduates by the total number of persons 25 years old and over. Tha data is collected from 2015 to 2019. |
# | Education.High School or Higher | Education High School+ | Float | Percentage of people whose highest degree was a high school diploma or its equivalent people who attended college but did not receive a degree and people who received an associate's bachelor's master's or professional or doctorate degree. These data include only persons 25 years old and over. The percentages are obtained by dividing the counts of graduates by the total number of persons 25 years old and over. Tha data is collected from 2015 to 2019 |
# | Employment.Nonemployer Establishments | Nonemployer Establishments | Integer | An establishment is a single physical location at which business is conducted or where services or industrial operations are performed. It is not necessarily identical with a company or enterprise which may consist of one establishment or more. The data was collected from 2018. |
# | Ethnicities.American Indian and Alaska Native Alone | American Indian and Alaska Native | Float | Estimated percentage of population having origins in any of the original peoples of North and South America (including Central America) and who maintains tribal affiliation or community attachment. This category includes people who indicate their race as "American Indian or Alaska Native" or report entries such as Navajo Blackfeet Inupiat Yup'ik or Central American Indian groups or South American Indian groups. |
# | Ethnicities.Asian Alone | Asian | Float | Estimated percentage of population having origins in any of the original peoples of the Far East Southeast Asia or the Indian subcontinent including for example Cambodia China India Japan Korea Malaysia Pakistan the Philippine Islands Thailand and Vietnam. This includes people who reported detailed Asian responses such as: "Asian Indian " "Chinese " "Filipino " "Korean " "Japanese " "Vietnamese " and "Other Asian" or provide other detailed Asian responses. |
# | Ethnicities.Black Alone | Black | Float | Estimated percentage of population having origins in any of the Black racial groups of Africa. It includes people who indicate their race as "Black or African American " or report entries such as African American Kenyan Nigerian or Haitian. |
# | Ethnicities.Hispanic or Latino | Hispanic or Latino | Float | Estimated percentage of population of Cuban Mexican Puerto Rican South or Central American or other Spanish culture or origin regardless of race. This includes people who reported detailed Hispanic or Latino groups. |
# | Ethnicities.Native Hawaiian and Other Pacific Islander Alone | Native Hawaiian or Pacific Islander | Float | Estimated percentage of population having origins in any of the Black racial groups of Africa. It includes people who indicate their race as "Black or African American " or report entries such as African American Kenyan Nigerian or Haitian. |
# | Ethnicities.Two or More Races | 2+ Races | Float | Estimated percentage of population choosing to provide two or more races either by checking two or more race response check boxes by providing multiple responses or by some combination of check boxes and other responses. For data product purposes "Two or More Races" refers to combinations of two or more of the following race categories: "White " "Black or African American " American Indian or Alaska Native " "Asian " Native Hawaiian or Other Pacific Islander " or "Some Other Race". |
# | Ethnicities.White Alone | White | Float | Estimated percentage of population having origins in any of the original peoples of Europe the Middle East or North Africa. It includes people who indicate their race as "White" or report entries such as Irish German Italian Lebanese Arab Moroccan or Caucasian. |
# | Ethnicities.White Alone not Hispanic or Latino | White not Hispanic or Latino | Float | Estimated percentage of population having origins in any of the original peoples of Europe the Middle East or North Africa. It includes people who indicate their race as "White" or report entries such as Irish German Italian Lebanese Arab Moroccan or Caucasian. |
# | Housing.Homeownership Rate | Homeownership Rate | Float | A housing unit is owner-occupied if the owner or co-owner lives in the unit even if it is mortgaged or not fully paid for. The owner or co-owner must live in the unit and usually is Person 1 on the questionnaire. This homeownership rate is computed by dividing the number of owner-occupied housing units by the number of occupied housing units or households from 2015 to 2019. |
# | Housing.Households | Households | Integer | Number of households including all the persons who occupy a housing unit as their usual place of residence from 2015 to 2019. |
# | Housing.Housing Units | Housing Units | Integer |	Estimated number of housing units apartments mobile homes groups of rooms or single rooms that are occupied (or if vacant is intended for occupancy) as separate living quarters beginning with July 1 2019. |
# | Housing.Median Value of Owner-Occupied Units | Median Value of Owner-Occupied Units | Integer | Median value of housing units which are owner-occupied if the owner or co-owner lives in the unit even if it is mortgaged or not fully paid for from 2015 to 2019. Median value calculations are rounded to the nearest hundred dollars. |
# | Housing.Persons per Household | Persons per Household | Float | Percentage for the number of people per household or average household size from 2015 to 2019. |
# | Income.Median Houseold Income | Median Household Income | Integer |	Median of income in the Past 12 Months collected from 2015 to 2019 - Income of Households: This includes the income of the householder and all other individuals 15 years old and over in the household whether they are related to the householder or not. Because many households consist of only one person average household income is usually less than average family income. |
# | Income.Per Capita Income | Per Capita Income | Integer | Per capita income is the mean income computed for every man woman and child in a particular group including those living in group quarters. It is derived by dividing the aggregate income of a particular group by the total population in that group. This measure is rounded to the nearest whole dollar. For the complete definition go to ACS subject definitions "Income in the Past 12 Months Per Capita Income." The data is collected from 2015 to 2019. |
# | Miscellaneous.Foreign Born | Foreign Born | Float | Estimated percentage of population who was not a U.S. citizen or a U.S. national at birth. This includes respondents who indicated they were a U.S. citizen by naturalization or not a U.S. citizen. from 2015 to 2019. |
# | Miscellaneous.Land Area | Land Area | Float | Land area measurements are originally recorded as whole square meters (to convert square meters to square kilometers divide by 1 000 000; to convert square kilometers to square miles divide by 2.58999; to convert square meters to square miles divide by 2 589 988) in 2010. |
# | Miscellaneous.Language Other than English at Home | Language Other than English | Float | Percentage for the number of people who knew languages other than English but did not use them at home who only used them elsewhere or whose usage was limited to a few expressions or slang were excluded from 2015 to 2019. Tabulations of language spoken at home include only the responses of persons 5 years old and over. |
# | Miscellaneous.Living in Same House +1 Years | Living in Same House 1+ Years | Float | Percentage for the residence in conjunction with location of current residence to determine the extent of residential mobility of the population and the resulting redistribution of the population across the various states metropolitan areas and regions of the country from 2015 to 2019. |
# | Miscellaneous.Manufacturers Shipments | Manufacturers Shipments | Integer |	The manufacturing sector comprises establishments engaged in the mechanical physical or chemical transformation of materials substances or components into new products. The 2012 Economic Census classifies businesses according to the North American Industry Classification System (NAICS) 2012. |
# | Miscellaneous.Mean Travel Time to Work | Mean Travel Time to Work | Float | Travel time to work refers to the total number of minutes that it usually took the person to get from home to work each day during the reference week. The elapsed time includes time spent waiting for public transportation picking up passengers in carpools and time spent in other activities related to getting to work. Mean travel time to work is obtained by dividing the total number of minutes by the number of workers 16 years old and over who did not work at home. Mean travel time to work is rounded to the nearest tenth of a minute. The data was collected from 2015 to 2019. |
# | Miscellaneous.Percent Female | Percent Female | Float | Estimated percentage of female population who are produced for the United States states and counties as well as for the Commonwealth of Puerto Rico and its municipios (county-equivalents for Puerto Rico). |
# | Miscellaneous.Veterans | Veterans | Integer | Population of men and women who have served (even for a short time) but are not currently serving on active duty in the U.S. Army Navy Air Force Marine Corps or the Coast Guard or who served in the U.S. Merchant Marine during World War II from 2015 to 2019. |
# | Population.2020 Population | 2020 Population | Integer | The population of people in a specified geographic area on April 1 2020. |
# | Population.2010 Population | 2010 Population | Integer | The population of people in a specified geographic area on April 1 2010. |
# | Population.Population per Square Mile | Population per Square Mile | Float | Population and housing unit density computed by dividing the total population or number of housing units within a geographic entity by the land area of that entity measured in square miles or in square kilometers in 2010. |
# | Sales.Accommodation and Food Services Sales | Accommodation and Food Services Sales | Integer | The Accommodation and Food Services Sales sector comprises establishments providing customers with lodging and/or prepared meals snacks and beverages for immediate consumption. The 2012 Economic Census classifies businesses according to the North American Industry Classification System (NAICS) 2012. Sales includes payments from customers for services rendered from the use of facilities and from merchandise sold. If tax-exempt sales includes dues and assessments from members and affiliates. |
# | Sales.Retail Sales | Retail Sales | Integer | The retail trade sector comprises establishments engaged in retailing merchandise generally without transformation and rendering services incidental to the sale of merchandise. The 2007 Economic Census classifies businesses according to the North American Industry Classification System (NAICS) 2012. Sales include merchandise sold for cash or credit at retail and wholesale by establishments primarily engaged in retail trade. |
# | Employment.Firms.Total | Total Firms | Integer | All nonfarm businesses filing Internal Revenue Service tax forms as individual proprietorships partnerships or any type of corporation and with receipts of $1 000 or more. The data was collected in 2012. |
# | Employment.Firms.Women-Owned | Women-Owned Firms | Integer | All women-owned nonfarm businesses filing Internal Revenue Service tax forms as individual proprietorships partnerships or any type of corporation and with receipts of $1 000 or more. The data was collected in 2012. |
# | Employment.Firms.Men-Owned | Men-Owned Firms | Integer | All men-owned nonfarm businesses filing Internal Revenue Service tax forms as individual proprietorships partnerships or any type of corporation and with receipts of $1 000 or more. The data was collected in 2012. |
# | Employment.Firms.Minority-Owned | Minority-Owned Firms | Integer	| All nonfarm businesses owned by equally minority filing Internal Revenue Service tax forms as individual proprietorships partnerships or any type of corporation and with receipts of $1 000 or more. The data was collected in 2012. |
# | Employment.Firms.Nonminority-Owned | Nonminority-Owned Firms | Integer | All nonfarm businesses owned by equally nonminority filing Internal Revenue Service tax forms as individual proprietorships partnerships or any type of corporation and with receipts of $1 000 or more. The data was collected in 2012. |
# | Employment.Firms.Veteran-Owned | Veteran-Owned Firms | Integer | All nonfarm businesses owned by veteran filing Internal Revenue Service tax forms as individual proprietorships partnerships or any type of corporation and with receipts of $1 000 or more. The data was collected in 2012. |
# | Employment.Firms.Nonveteran-Owned | Nonveteran-Owned Firms | Integer | All nonfarm businesses owned by non-veteran filing Internal Revenue Service tax forms as individual proprietorships partnerships or any type of corporation and with receipts of $1 000 or more. The data was collected in 2012. |

# %% [markdown]
# ## Exploratory Data Analysis
# Before beginning any analysis, we will perform some exploratory data analysis to explore trends and relationships amongst different variables of interest in our dataset.

# %%
# Imports
# !pip install -q pandas
# !pip install -q numpy
# !pip install --upgrade --q pip
# !pip install -q sqlalchemy==1.4.46
# !pip install pandas --q pandasql 


import pandas as pd
import numpy as np
from sqlalchemy import text, sql
from pandasql import sqldf
import matplotlib.pyplot as plt

# %%
county_demo_df = pd.read_csv('county_demographics.csv')
county_demo_df.head()
# Out:
#              County State  Age.Percent 65 and Older  \
# 0  Abbeville County    SC                      22.4
# 1     Acadia Parish    LA                      15.8
# 2   Accomack County    VA                      24.6
# 3        Ada County    ID                      14.9
# 4      Adair County    IA                      23.0
#
#    Age.Percent Under 18 Years  Age.Percent Under 5 Years  \
# 0                        19.8                        4.7
# 1                        25.8                        6.9
# 2                        20.7                        5.6
# 3                        23.2                        5.6
# 4                        21.8                        5.6
#
#    Education.Bachelor's Degree or Higher  Education.High School or Higher  \
# 0                                   15.6                             81.7
# 1                                   13.3                             79.0
# 2                                   19.5                             81.5
# ...

# %% [markdown]
# For the purposes of using SQL, I will be renaming several of the column names to make querying simpler. The table in the beginning shows the original and renamed column names.

# %%
county_demo_df.columns
county_demo_df = county_demo_df.rename(columns = {
    'Age.Percent 65 and Older': 'Age 65+', 
    'Age.Percent Under 18 Years': 'Age Under 18',
    'Age.Percent Under 5 Years': 'Age Under 5', 
    "Education.Bachelor's Degree or Higher": "Education Bachelor's+",
    "Education.High School or Higher": "Education High School+", 
    'Employment.Nonemployer Establishments': 'Nonemployer Establishments',
    'Ethnicities.American Indian and Alaska Native Alone': 'American Indian and Alaska Native', 
    'Ethnicities.Asian Alone': 'Asian', 
    'Ethnicities.Black Alone': 'Black', 
    'Ethnicities.Hispanic or Latino': 'Hispanic or Latino', 
    'Ethnicities.Native Hawaiian and Other Pacific Islander Alone': 'Native Hawaiian or Pacific Islander', 
    'Ethnicities.Two or More Races': '2+ Races', 
    'Ethnicities.White Alone': 'White', 
    'Ethnicities.White Alone\t not Hispanic or Latino': 'White not Hispanic or Latino',
    'Housing.Homeownership Rate': 'Homeownership Rate', 
    'Housing.Households': 'Households', 
    'Housing.Housing Units': 'Housing Units', 
    'Housing.Median Value of Owner-Occupied Units': 'Median Value of Owner-Occupied Units', 
    'Housing.Persons per Household': 'Persons per Household', 
    'Income.Median Houseold Income': 'Median Household Income', 
    'Income.Per Capita Income': 'Per Capita Income', 
    'Miscellaneous.Foreign Born': 'Foreign Born', 
    'Miscellaneous.Land Area': 'Land Area',
    'Miscellaneous.Language Other than English at Home': 'Language Other than English', 
    'Miscellaneous.Living in Same House +1 Years': 'Living in Same House 1+ Years', 
    'Miscellaneous.Manufacturers Shipments': 'Manufacturers Shipments', 
    'Miscellaneous.Mean Travel Time to Work': 'Mean Travel Time to Work', 
    'Miscellaneous.Percent Female': 'Percent Female', 
    'Miscellaneous.Veterans': 'Veterans',
    'Population.2020 Population': '2020 Population',
    'Population.2010 Population': '2010 Population', 
    'Population.Population per Square Mile': 'Population per Square Mile',
    'Sales.Accommodation and Food Services Sales': 'Accomodation and Food Services Sales', 
    'Sales.Retail Sales': 'Retail Sales', 
    'Employment.Firms.Total': 'Total Firms', 
    'Employment.Firms.Women-Owned': 'Women-Owned Firms', 
    'Employment.Firms.Men-Owned': 'Men-Owned Firms', 
    'Employment.Firms.Minority-Owned': 'Minority-Owned Firms', 
    'Employment.Firms.Nonminority-Owned': 'Nonminority-Owned Firms', 
    'Employment.Firms.Veteran-Owned': 'Veteran-Owned Firms', 
    'Employment.Firms.Nonveteran-Owned': 'Nonveteran-Owned Firms'
})

# %%
county_demo_df.columns
county_demo_df[['Age 65+']]
# Out:
#       Age 65+
# 0        22.4
# 1        15.8
# 2        24.6
# 3        14.9
# 4        23.0
# ...       ...
# 3134     19.3
# 3135     18.7
# 3136     13.2
# 3137     14.6
# 3138      9.6
#
# [3139 rows x 1 columns]

# %%
county_demo_df.head()
# Out:
#              County State  Age 65+  Age Under 18  Age Under 5  \
# 0  Abbeville County    SC     22.4          19.8          4.7
# 1     Acadia Parish    LA     15.8          25.8          6.9
# 2   Accomack County    VA     24.6          20.7          5.6
# 3        Ada County    ID     14.9          23.2          5.6
# 4      Adair County    IA     23.0          21.8          5.6
#
#    Education Bachelor's+  Education High School+  Nonemployer Establishments  \
# 0                   15.6                    81.7                        1416
# 1                   13.3                    79.0                        4533
# 2                   19.5                    81.5                        2387
# 3                   38.5                    95.2                       41464
# 4                   18.5                    94.2                         609
#
#    American Indian and Alaska Native  Asian  ...  Population per Square Mile  \
# ...

# %%
query = ''' SELECT "County", "State" from county_demo_df where "State" = "CA" '''
sqldf(query, env = None)
# Out:
#                     County State
# 0           Alameda County    CA
# 1            Alpine County    CA
# 2            Amador County    CA
# 3             Butte County    CA
# 4         Calaveras County    CA
# 5            Colusa County    CA
# 6      Contra Costa County    CA
# 7         Del Norte County    CA
# 8         El Dorado County    CA
# 9            Fresno County    CA
# 10            Glenn County    CA
# 11         Humboldt County    CA
# 12         Imperial County    CA
# 13             Inyo County    CA
# 14             Kern County    CA
# 15            Kings County    CA
# 16             Lake County    CA
# 17           Lassen County    CA
# 18      Los Angeles County    CA
# 19           Madera County    CA
# 20            Marin County    CA
# 21         Mariposa County    CA
# 22        Mendocino County    CA
# 23           Merced County    CA
# 24            Modoc County    CA
# 25             Mono County    CA
# 26         Monterey County    CA
# ...

# %%
query = ''' SELECT "State", count(*) as Count from county_demo_df group by "State" '''
result = sqldf(query, env = None)
print(result)

fig = plt.figure(figsize = (20, 8))
plt.bar(result["State"], result["Count"])

for index, value in enumerate(result["Count"]):
    plt.text(index -  0.30, value + 3, str(value))

plt.xlabel("State")
plt.ylabel("Count")
plt.title("Number of Counties in Each State")
# Out:
#    State  Count
# 0     AK     27
# 1     AL     67
# 2     AR     75
# 3     AZ     15
# 4     CA     58
# 5     CO     64
# 6     CT      8
# 7     DC      1
# 8     DE      3
# 9     FL     67
# 10    GA    159
# 11    HI      5
# 12    IA     99
# 13    ID     44
# 14    IL    102
# 15    IN     92
# 16    KS    105
# 17    KY    120
# 18    LA     64
# 19    MA     14
# 20    MD     24
# 21    ME     16
# 22    MI     83
# 23    MN     87
# 24    MO    115
# 25    MS     82
# 26    MT     56
# 27    NC    100
# 28    ND     53
# 29    NE     93
# 30    NH     10
# 31    NJ     21
# 32    NM     33
# 33    NV     17
# 34    NY     62
# 35    OH     88
# 36    OK     77
# 37    OR     36
# 38    PA     67
# 39    RI      5
# 40    SC     46
# 41    SD     65
# 42    TN     95
# 43    TX    254
# 44    UT     29
# 45    VA    133
# 46    VT     14
# 47    WA     39
# 48    WI     72
# 49    WV     55
# 50    WY     23
# Text(0.5, 1.0, 'Number of Counties in Each State')

# %%
query = '''SELECT AVG("Asian") from county_demo_df'''
result = sqldf(query, env = None)
print(result)
# Out:
#    AVG("Asian")
# 0      1.573463

# %% [markdown]
# The query above tells us that the average percentage of Asians in all US counties is about 1.57%.

# %%
query = '''SELECT "County", "State", "Asian" from county_demo_df where "Asian" > (SELECT AVG("Asian") from county_demo_df)'''
result = sqldf(query, env = None)
print(result)
# Out:
#              County State  Asian
# 0        Ada County    ID    2.7
# 1      Adair County    MO    2.6
# 2      Adams County    CO    4.5
# 3      Adams County    ND    2.8
# 4    Addison County    VT    1.8
# ..              ...   ...    ...
# 723  Yamhill County    OR    2.0
# 724     Yolo County    CA   15.1
# 725     York County    SC    2.8
# 726     York County    VA    6.1
# 727     Yuba County    CA    7.3
#
# [728 rows x 3 columns]

# %% [markdown]
# There are 728 US counties where the percentage of Asians is above the national average of 1.57%. To take this query one step further, we will count the number of counties in each state where this holds true.

# %%
query = '''SELECT "State", count(*) as Count from county_demo_df where "Asian" > (SELECT AVG("Asian") from county_demo_df) group by "State"'''
result = sqldf(query, env = None)
print(result)

fig = plt.figure(figsize = (16, 8))
plt.bar(result["State"], result["Count"])

for index, value in enumerate(result["Count"]):
    plt.text(index -  0.30, value + 0.5, str(value))

plt.xlabel("State")
plt.ylabel("Count")
plt.title("Number of Counties in Each State")
# Out:
#    State  Count
# 0     AK     19
# 1     AL     11
# 2     AR      8
# 3     AZ      5
# 4     CA     50
# 5     CO     14
# 6     CT      7
# 7     DC      1
# 8     DE      2
# 9     FL     31
# 10    GA     37
# 11    HI      5
# 12    IA     19
# 13    ID      6
# 14    IL     18
# 15    IN     17
# 16    KS     17
# 17    KY      9
# 18    LA     12
# 19    MA     13
# 20    MD     14
# 21    ME      1
# 22    MI     15
# 23    MN     24
# 24    MO     15
# 25    MS      6
# 26    MT      3
# 27    NC     26
# 28    ND      7
# 29    NE      7
# 30    NH      6
# 31    NJ     18
# 32    NM      7
# 33    NV      9
# 34    NY     27
# 35    OH     18
# 36    OK     11
# 37    OR     11
# 38    PA     19
# 39    RI      5
# 40    SC     11
# 41    SD      9
# 42    TN     12
# 43    TX     44
# 44    UT      7
# 45    VA     47
# 46    VT      2
# 47    WA     22
# 48    WI     19
# 49    WV      2
# 50    WY      3
# Text(0.5, 1.0, 'Number of Counties in Each State')

# %% [markdown]
# The bar graph above tells us that California, Virginia, and Texas have the most number of counties where the Asian population is above the national average. However, because each state has a different number of counties, it makes sense to calculate the proportion of counties that have an Asian population higher than the national average for each state. The query below will perform this calculation.

# %%
query1 = '''SELECT "State", count(*) as Count from county_demo_df where "Asian" > (SELECT AVG("Asian") from county_demo_df) group by "State"'''
result1 = sqldf(query1, env = None)
print(result1)
# Out:
#    State  Count
# 0     AK     19
# 1     AL     11
# 2     AR      8
# 3     AZ      5
# 4     CA     50
# 5     CO     14
# 6     CT      7
# 7     DC      1
# 8     DE      2
# 9     FL     31
# 10    GA     37
# 11    HI      5
# 12    IA     19
# 13    ID      6
# 14    IL     18
# 15    IN     17
# 16    KS     17
# 17    KY      9
# 18    LA     12
# 19    MA     13
# 20    MD     14
# 21    ME      1
# 22    MI     15
# 23    MN     24
# 24    MO     15
# 25    MS      6
# 26    MT      3
# 27    NC     26
# 28    ND      7
# 29    NE      7
# 30    NH      6
# 31    NJ     18
# 32    NM      7
# 33    NV      9
# 34    NY     27
# 35    OH     18
# 36    OK     11
# 37    OR     11
# 38    PA     19
# 39    RI      5
# 40    SC     11
# 41    SD      9
# 42    TN     12
# 43    TX     44
# 44    UT      7
# 45    VA     47
# 46    VT      2
# 47    WA     22
# 48    WI     19
# 49    WV      2
# 50    WY      3

# %%
query2 = '''SELECT "State", count(*) as Count from county_demo_df group by "State"'''
result2 = sqldf(query2, env = None)
print(result2)
# Out:
#    State  Count
# 0     AK     27
# 1     AL     67
# 2     AR     75
# 3     AZ     15
# 4     CA     58
# 5     CO     64
# 6     CT      8
# 7     DC      1
# 8     DE      3
# 9     FL     67
# 10    GA    159
# 11    HI      5
# 12    IA     99
# 13    ID     44
# 14    IL    102
# 15    IN     92
# 16    KS    105
# 17    KY    120
# 18    LA     64
# 19    MA     14
# 20    MD     24
# 21    ME     16
# 22    MI     83
# 23    MN     87
# 24    MO    115
# 25    MS     82
# 26    MT     56
# 27    NC    100
# 28    ND     53
# 29    NE     93
# 30    NH     10
# 31    NJ     21
# 32    NM     33
# 33    NV     17
# 34    NY     62
# 35    OH     88
# 36    OK     77
# 37    OR     36
# 38    PA     67
# 39    RI      5
# 40    SC     46
# 41    SD     65
# 42    TN     95
# 43    TX    254
# 44    UT     29
# 45    VA    133
# 46    VT     14
# 47    WA     39
# 48    WI     72
# 49    WV     55
# 50    WY     23

# %%
fig = plt.figure(figsize = (25, 10))
diff = (result1["Count"] / result2["Count"]).round(2)
plt.bar(result1["State"], diff)

for index, value in enumerate(diff):
    plt.text(index-0.5, value + 0.01, str(value))

plt.xlabel("State")
plt.ylabel("Count")
plt.title("Proportion of Counties in Each State Where Asian Population is Higher than National Average")
# Out:
# Text(0.5, 1.0, 'Proportion of Counties in Each State Where Asian Population is Higher than National Average')

# %% [markdown]
# From the bar graph above, Washington DC, Hawaii, and Rhode Island all have proportions of 1.0, which means that all of the counties in those states have an Asian population that is above the national average of 1.57%. While California, Texas, and Virginia may have the most counties with an Asian population higher than the national average, this large amount is also partly due to the fact that these states have a large number of counties. Namely, Texas has 254 counties but only 44 of those counties have an Asian population higher than the national average. Thus, the proportion for Texas is only 0.17, which is a lot lower compared to many other states, as shown in the bar graph above.
